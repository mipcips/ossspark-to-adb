# %%
from pyspark import SparkConf, SparkContext

# %%
conf = SparkConf().set("spark.executor.memory", "2g")

# %%
sc = SparkContext(conf = conf)

# %%
rdd = sc.range(1,2000000)

# %%
rdd.collect()

# %%
sc.stop()
